# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score
pd.options.display.float_format = '{:.1f}'.format

# %%
Datos = pd.read_csv('./Car details v3.csv')
Datos['engine_2'] = Datos['engine'].str.extract('(\d+\.?\d*)').astype(float)
Datos['engine'] = Datos['engine_2']

# %%
Datos.head(50)
# Out:
#                                            name  year  selling_price  \
# 0                        Maruti Swift Dzire VDI  2014         450000
# 1                  Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                      Honda City 2017-2020 EXi  2006         158000
# 3                     Hyundai i20 Sportz Diesel  2010         225000
# 4                        Maruti Swift VXI BSIII  2007         130000
# 5                 Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6                  Maruti Wagon R LXI DUO BSIII  2007          96000
# 7                            Maruti 800 DX BSII  2001          45000
# 8                              Toyota Etios VXD  2011         350000
# 9          Ford Figo Diesel Celebration Edition  2013         200000
# 10              Renault Duster 110PS Diesel RxL  2014         500000
# 11                                Maruti Zen LX  2005          92000
# 12                       Maruti Swift Dzire VDi  2009         280000
# 13                         Maruti Swift 1.3 VXi  2007         200000
# 14                     Maruti Wagon R LXI Minor  2009         180000
# 15         Mahindra KUV 100 mFALCON G80 K8 5str  2016         400000
# 16                       Maruti Ertiga SHVS VDI  2016         778000
# 17                    Hyundai i20 1.4 CRDi Asta  2012         500000
# 18                               Maruti Alto LX  2002         150000
# 19          Hyundai i20 2015-2017 Asta 1.4 CRDi  2016         680000
# 20                 Mahindra Verito 1.5 D4 BSIII  2011         174000
# 21                         Honda WR-V i-DTEC VX  2017         950000
# 22                       Maruti Swift Dzire ZDI  2015         525000
# 23                               Maruti SX4 ZDI  2012         600000
# 24                      Tata Tigor 2017-2020 XZ  2018         500000
# 25                      Maruti Baleno Delta 1.2  2016         575000
# 26                          Maruti Alto 800 LXI  2017         275000
# 27            Chevrolet Enjoy TCDi LTZ 7 Seater  2013         300000
# 28                     Maruti Wagon R LXI Minor  2009         220000
# 29                  Maruti Omni E MPI STD BS IV  2018         254999
# 30              Maruti Vitara Brezza LDi Option  2017         670000
# 31                           Fiat Palio 1.2 ELX  2003          70000
# 32                    Maruti Omni 8 Seater BSIV  2012         150000
# 33               Hyundai i20 1.2 Asta Dual Tone  2018         730000
# 34                     Maruti Vitara Brezza LDi  2017         650000
# 35             Maruti Alto 800 CNG LXI Optional  2019         330000
# 36                   Maruti Alto K10 VXI Airbag  2019         366000
# 37             Hyundai Verna VTVT 1.6 SX Option  2019        1149000
# 38                                  Datsun GO D  2016         150000
# 39                 Tata Safari DICOR 2.2 LX 4x2  2011         425000
# 40                               Maruti 800 Std  2012         150000
# 41           Jeep Compass 1.4 Limited Plus BSIV  2019        2100000
# 42                         Honda City i VTEC VX  2018         925000
# 43                              Honda City V MT  2013         425000
# 44                    Maruti Swift Dzire VXi AT  2018         675000
# 45                     Maruti Vitara Brezza VDi  2018         819999
# 46                          Maruti Alto K10 VXI  2018         390000
# 47                       Toyota Fortuner 4x4 MT  2014        1500000
# 48  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2013         700000
# 49                   Mercedes-Benz B Class B180  2014        1450000
#
#     km_driven    fuel seller_type transmission         owner      mileage  \
# 0      145500  Diesel  Individual       Manual   First Owner    23.4 kmpl
# 1      120000  Diesel  Individual       Manual  Second Owner   21.14 kmpl
# 2      140000  Petrol  Individual       Manual   Third Owner    17.7 kmpl
# 3      127000  Diesel  Individual       Manual   First Owner    23.0 kmpl
# 4      120000  Petrol  Individual       Manual   First Owner    16.1 kmpl
# 5       45000  Petrol  Individual       Manual   First Owner   20.14 kmpl
# 6      175000     LPG  Individual       Manual   First Owner   17.3 km/kg
# 7        5000  Petrol  Individual       Manual  Second Owner    16.1 kmpl
# 8       90000  Diesel  Individual       Manual   First Owner   23.59 kmpl
# 9      169000  Diesel  Individual       Manual   First Owner    20.0 kmpl
# 10      68000  Diesel  Individual       Manual  Second Owner   19.01 kmpl
# 11     100000  Petrol  Individual       Manual  Second Owner    17.3 kmpl
# 12     140000  Diesel  Individual       Manual  Second Owner    19.3 kmpl
# 13      80000  Petrol  Individual       Manual  Second Owner          NaN
# 14      90000  Petrol  Individual       Manual  Second Owner    18.9 kmpl
# 15      40000  Petrol  Individual       Manual   First Owner   18.15 kmpl
# 16      70000  Diesel  Individual       Manual  Second Owner   24.52 kmpl
# 17      53000  Diesel  Individual       Manual  Second Owner    23.0 kmpl
# 18      80000  Petrol  Individual       Manual  Second Owner    19.7 kmpl
# 19     100000  Diesel  Individual       Manual   First Owner   22.54 kmpl
# 20     100000  Diesel  Individual       Manual  Second Owner    21.0 kmpl
# 21      50000  Diesel  Individual       Manual   First Owner    25.5 kmpl
# 22      40000  Diesel  Individual       Manual   First Owner   26.59 kmpl
# 23      72000  Diesel  Individual       Manual   First Owner    21.5 kmpl
# 24      35000  Petrol  Individual       Manual   First Owner    20.3 kmpl
# 25      45000  Petrol  Individual       Manual   First Owner    21.4 kmpl
# 26      28000  Petrol  Individual       Manual   First Owner    24.7 kmpl
# 27      70000  Diesel  Individual       Manual   First Owner    18.2 kmpl
# 28     120000  Petrol  Individual       Manual   First Owner    18.9 kmpl
# 29      25000  Petrol  Individual       Manual   First Owner    16.8 kmpl
# 30      70000  Diesel  Individual       Manual   First Owner    24.3 kmpl
# 31      50000  Petrol  Individual       Manual  Second Owner          NaN
# 32      35000  Petrol  Individual       Manual  Second Owner    14.0 kmpl
# 33       2388  Petrol  Individual       Manual   First Owner    18.6 kmpl
# 34      16200  Diesel  Individual       Manual   First Owner    24.3 kmpl
# 35      10000     CNG  Individual       Manual  Second Owner  33.44 km/kg
# 36      15000  Petrol  Individual       Manual   First Owner   23.95 kmpl
# 37       5000  Petrol  Individual       Manual   First Owner    17.0 kmpl
# 38      42000  Petrol  Individual       Manual   First Owner   20.63 kmpl
# 39      60000  Diesel  Individual       Manual  Second Owner   13.93 kmpl
# 40      76000  Petrol  Individual       Manual   First Owner    16.1 kmpl
# 41       5000  Petrol  Individual    Automatic   First Owner    16.0 kmpl
# 42      28900  Petrol      Dealer       Manual   First Owner    17.8 kmpl
# 43      86300  Petrol      Dealer       Manual   First Owner    16.8 kmpl
# 44      23300  Petrol      Dealer    Automatic   First Owner    18.5 kmpl
# 45      32600  Diesel      Dealer       Manual   First Owner    24.3 kmpl
# 46      10300  Petrol      Dealer       Manual   First Owner   23.95 kmpl
# 47      77000  Diesel      Dealer       Manual   First Owner   12.55 kmpl
# 48      99000  Diesel      Dealer       Manual   First Owner   12.99 kmpl
# 49      27800  Diesel      Dealer    Automatic  Second Owner    14.8 kmpl
#
#     engine   max_power                    torque  seats  engine_2
# 0   1248.0      74 bhp            190Nm@ 2000rpm    5.0    1248.0
# 1   1498.0  103.52 bhp       250Nm@ 1500-2500rpm    5.0    1498.0
# 2   1497.0      78 bhp     12.7@ 2,700(kgm@ rpm)    5.0    1497.0
# 3   1396.0      90 bhp  22.4 kgm at 1750-2750rpm    5.0    1396.0
# 4   1298.0    88.2 bhp     11.5@ 4,500(kgm@ rpm)    5.0    1298.0
# 5   1197.0   81.86 bhp         113.75nm@ 4000rpm    5.0    1197.0
# 6   1061.0    57.5 bhp      7.8@ 4,500(kgm@ rpm)    5.0    1061.0
# 7    796.0      37 bhp             59Nm@ 2500rpm    4.0     796.0
# 8   1364.0    67.1 bhp       170Nm@ 1800-2400rpm    5.0    1364.0
# 9   1399.0    68.1 bhp            160Nm@ 2000rpm    5.0    1399.0
# 10  1461.0  108.45 bhp            248Nm@ 2250rpm    5.0    1461.0
# 11   993.0      60 bhp             78Nm@ 4500rpm    5.0     993.0
# 12  1248.0    73.9 bhp            190Nm@ 2000rpm    5.0    1248.0
# 13     NaN         NaN                       NaN    NaN       NaN
# 14  1061.0      67 bhp             84Nm@ 3500rpm    5.0    1061.0
# 15  1198.0      82 bhp       115Nm@ 3500-3600rpm    5.0    1198.0
# 16  1248.0    88.5 bhp            200Nm@ 1750rpm    7.0    1248.0
# 17  1396.0      90 bhp  22.4 kgm at 1750-2750rpm    5.0    1396.0
# 18   796.0    46.3 bhp             62Nm@ 3000rpm    5.0     796.0
# 19  1396.0   88.73 bhp     219.7Nm@ 1500-2750rpm    5.0    1396.0
# 20  1461.0    64.1 bhp            160Nm@ 2000rpm    5.0    1461.0
# 21  1498.0    98.6 bhp            200Nm@ 1750rpm    5.0    1498.0
# 22  1248.0      74 bhp            190Nm@ 2000rpm    5.0    1248.0
# 23  1248.0    88.8 bhp            200Nm@ 1750rpm    5.0    1248.0
# 24  1199.0   83.81 bhp            114Nm@ 3500rpm    5.0    1199.0
# 25  1197.0    83.1 bhp            115Nm@ 4000rpm    5.0    1197.0
# 26   796.0    47.3 bhp             69Nm@ 3500rpm    5.0     796.0
# 27  1248.0    73.8 bhp          172.5Nm@ 1750rpm    7.0    1248.0
# 28  1061.0      67 bhp             84Nm@ 3500rpm    5.0    1061.0
# 29   796.0    34.2 bhp             59Nm@ 2500rpm    8.0     796.0
# 30  1248.0    88.5 bhp            200Nm@ 1750rpm    5.0    1248.0
# 31     NaN         NaN                       NaN    NaN       NaN
# 32   796.0      35 bhp           6.1kgm@ 3000rpm    5.0     796.0
# 33  1197.0   81.83 bhp          114.7Nm@ 4000rpm    5.0    1197.0
# 34  1248.0    88.5 bhp            200Nm@ 1750rpm    5.0    1248.0
# 35   796.0    40.3 bhp             60Nm@ 3500rpm    4.0     796.0
# 36   998.0    67.1 bhp             90Nm@ 3500rpm    5.0     998.0
# 37  1591.0   121.3 bhp            151Nm@ 4850rpm    5.0    1591.0
# 38  1198.0      67 bhp            104Nm@ 4000rpm    5.0    1198.0
# 39  2179.0  138.03 bhp       320Nm@ 1700-2700rpm    7.0    2179.0
# 40   796.0      37 bhp             59Nm@ 2500rpm    4.0     796.0
# 41  1368.0  160.77 bhp       250Nm@ 1750-2500rpm    5.0    1368.0
# 42  1497.0   117.3 bhp            145Nm@ 4600rpm    5.0    1497.0
# 43  1497.0   116.3 bhp            146Nm@ 4800rpm    5.0    1497.0
# 44  1197.0   83.14 bhp            115Nm@ 4000rpm    5.0    1197.0
# 45  1248.0    88.5 bhp            200Nm@ 1750rpm    5.0    1248.0
# 46   998.0   67.05 bhp             90Nm@ 3500rpm    5.0     998.0
# 47  2982.0   168.5 bhp       343Nm@ 1400-3400rpm    7.0    2982.0
# 48  2494.0     100 bhp       200Nm@ 1400-3400rpm    7.0    2494.0
# 49  2143.0   120.7 bhp       200Nm@ 1250-4000rpm    5.0    2143.0

# %%
Datos.describe()
# Out:
#         year  selling_price  km_driven  seats
# count 8128.0         8128.0     8128.0 7907.0
# mean  2013.8       638271.8    69819.5    5.4
# std      4.0       806253.4    56550.6    1.0
# min   1983.0        29999.0        1.0    2.0
# 25%   2011.0       254999.0    35000.0    5.0
# 50%   2015.0       450000.0    60000.0    5.0
# 75%   2017.0       675000.0    98000.0    5.0
# max   2020.0     10000000.0  2360457.0   14.0

# %%
plt.figure(figsize=(6,3))
sns.boxplot(x=Datos['selling_price'])
plt.title('Identificacion de Datos faltantes y atípicos', fontsize=10) #Dado el precio de vehiculos en subasta los precios no se consideran outliers
# Out:
# Text(0.5, 1.0, 'Identificacion de Datos faltantes y atípicos')

# %%
print("Cantidad de registros con cero en name: ",Datos['name'].isin([0]).sum())
print("Cantidad de registros con cero en year: ",Datos['year'].isin([0]).sum())
print("Cantidad de registros con cero en selling_price: ",Datos['selling_price'].isin([0]).sum())
print("Cantidad de registros con cero en km_driven: ",Datos['km_driven'].isin([0]).sum())
print("Cantidad de registros con cero en fuel: ",Datos['fuel'].isin([0]).sum())
print("Cantidad de registros con cero en seller_type: ",Datos['seller_type'].isin([0]).sum())
print("Cantidad de registros con cero en transmission: ",Datos['transmission'].isin([0]).sum())
print("Cantidad de registros con cero en owner: ",Datos['owner'].isin([0]).sum())
print("Cantidad de registros con cero en mileage: ",Datos['mileage'].isin([0]).sum())
print("Cantidad de registros con cero en engine: ",Datos['engine'].isin([0]).sum())
print("Cantidad de registros con cero en max_power: ",Datos['max_power'].isin([0]).sum())
print("Cantidad de registros con cero en torque: ",Datos['torque'].isin([0]).sum())
print("Cantidad de registros con cero en seats: ",Datos['seats'].isin([0]).sum())
print("Cantidad de registros con Nan en name: ",Datos['name'].isnull().sum())
print("Cantidad de registros con Nan en year: ",Datos['year'].isnull().sum())
print("Cantidad de registros con Nan en selling_price: ",Datos['selling_price'].isnull().sum())
print("Cantidad de registros con Nan en km_driven: ",Datos['km_driven'].isnull().sum())
print("Cantidad de registros con Nan en fuel: ",Datos['fuel'].isnull().sum())
print("Cantidad de registros con Nan en seller_type: ",Datos['seller_type'].isnull().sum())
print("Cantidad de registros con Nan en transmission: ",Datos['transmission'].isnull().sum())
print("Cantidad de registros con Nan en owner: ",Datos['owner'].isnull().sum())
print("Cantidad de registros con Nan en mileage: ",Datos['mileage'].isnull().sum())
print("Cantidad de registros con Nan en engine: ",Datos['engine'].isnull().sum())
print("Cantidad de registros con Nan en max_power: ",Datos['max_power'].isnull().sum())
print("Cantidad de registros con Nan en torque: ",Datos['torque'].isnull().sum())
print("Cantidad de registros con Nan en seats: ",Datos['seats'].isnull().sum())
# Out:
# Cantidad de registros con cero en name:  0
# Cantidad de registros con cero en year:  0
# Cantidad de registros con cero en selling_price:  0
# Cantidad de registros con cero en km_driven:  0
# Cantidad de registros con cero en fuel:  0
# Cantidad de registros con cero en seller_type:  0
# Cantidad de registros con cero en transmission:  0
# Cantidad de registros con cero en owner:  0
# Cantidad de registros con cero en mileage:  0
# Cantidad de registros con cero en engine:  0
# Cantidad de registros con cero en max_power:  0
# Cantidad de registros con cero en torque:  0
# Cantidad de registros con cero en seats:  0
# Cantidad de registros con Nan en name:  0
# Cantidad de registros con Nan en year:  0
# Cantidad de registros con Nan en selling_price:  0
# Cantidad de registros con Nan en km_driven:  0
# Cantidad de registros con Nan en fuel:  0
# Cantidad de registros con Nan en seller_type:  0
# Cantidad de registros con Nan en transmission:  0
# Cantidad de registros con Nan en owner:  0
# Cantidad de registros con Nan en mileage:  221
# Cantidad de registros con Nan en engine:  221
# Cantidad de registros con Nan en max_power:  215
# Cantidad de registros con Nan en torque:  222
# Cantidad de registros con Nan en seats:  221

# %%
Datos.isnull().sum()*100/Datos.shape[0]
# Out:
# name            0.0
# year            0.0
# selling_price   0.0
# km_driven       0.0
# fuel            0.0
# seller_type     0.0
# transmission    0.0
# owner           0.0
# mileage         2.7
# engine          2.7
# max_power       2.6
# torque          2.7
# seats           2.7
# dtype: float64

# %%
Datos= Datos.dropna() #eliminamos valores nulos

# %%
print("Cantidad de registros con Nan en mileage: ",Datos['mileage'].isnull().sum())
print("Cantidad de registros con Nan en engine: ",Datos['engine'].isnull().sum())
print("Cantidad de registros con Nan en max_power: ",Datos['max_power'].isnull().sum())
print("Cantidad de registros con Nan en torque: ",Datos['torque'].isnull().sum())
print("Cantidad de registros con Nan en seats: ",Datos['seats'].isnull().sum())
# Out:
# Cantidad de registros con Nan en mileage:  0
# Cantidad de registros con Nan en engine:  0
# Cantidad de registros con Nan en max_power:  0
# Cantidad de registros con Nan en torque:  0
# Cantidad de registros con Nan en seats:  0

# %%
Datos.isnull().sum()*100/Datos.shape[0] #no hay valores nulos
# Out:
# name            0.0
# year            0.0
# selling_price   0.0
# km_driven       0.0
# fuel            0.0
# seller_type     0.0
# transmission    0.0
# owner           0.0
# mileage         0.0
# engine          0.0
# max_power       0.0
# torque          0.0
# seats           0.0
# dtype: float64

# %%
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 864.7+ KB

# %% [markdown]
# 3.Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características
# Característica de interes:
#
# selling_price: determinar el precio de venta del vehiculo
# Predecir el precio de venta del vehiculo

# %%
Datos['selling_price'].value_counts()
# Out:
# selling_price
# 300000    221
# 600000    211
# 350000    204
# 550000    204
# 450000    194
#          ...
# 67500       1
# 66000       1
# 312000      1
# 298000      1
# 746000      1
# Name: count, Length: 670, dtype: int64

# %%
Datos['selling_price'].head(10)
# Out:
# 0    450000
# 1    370000
# 2    158000
# 3    225000
# 4    130000
# 5    440000
# 6     96000
# 7     45000
# 8    350000
# 9    200000
# Name: selling_price, dtype: int64

# %% [markdown]
# 4. Dividir el dataset en Train y Test para evaluar correctamente el modelo

# %%
Datos = Datos[['selling_price', 'year','km_driven','engine','seats']]
X = Datos.drop('selling_price',axis=1)
Y = Datos['selling_price']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25, random_state = 0 )

# %%
print(X_train)
# Out:
#       year  km_driven  engine  seats
# 1075  2016      94000  2755.0    7.0
# 3139  2015      90000  1498.0    5.0
# 1682  2015      20000  1248.0    5.0
# 5555  2018      50000   998.0    5.0
# 6571  2016      11000  1598.0    5.0
# ...    ...        ...     ...    ...
# 5074  2011     105000  1497.0    5.0
# 3367  2016      38000  1197.0    5.0
# 1703  2015      35000  1497.0    7.0
# 2694  2013     173000  2179.0    7.0
# 2821  2007     100000  1405.0    5.0
#
# [5929 rows x 4 columns]

# %%
print(Y_train)
# Out:
# 1075    1825000
# 3139     455000
# 1682     700000
# 5555     459999
# 6571     645000
#          ...
# 5074     421000
# 3367     540000
# 1703     500000
# 2694     479000
# 2821     130000
# Name: selling_price, Length: 5929, dtype: int64

# %% [markdown]
# 5. Entrenar el modelo configurando los diferentes hiperparámetros

# %%
#modelo_regresion = LogisticRegression(solver = 'liblinear')
modelo_regresion = LinearRegression()
modelo_regresion.fit(X_train,Y_train)
Prediccion = modelo_regresion.predict(X_test)

# %%
print(Y_test)
# Out:
# 4048     430000
# 4831     779000
# 5123     200000
# 6505     800000
# 46       390000
#          ...
# 7345     650000
# 6569    5500000
# 3627     430000
# 6038     200000
# 1860    4100000
# Name: selling_price, Length: 1977, dtype: int64

# %%
print(Prediccion)
# Out:
# [ 753868.71379519  950709.64796853  355673.73374131 ...  578403.6323114
#   414308.58260259 3497001.60562235]

# %% [markdown]
# 6. Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc

# %%
r2 = r2_score(Y_test, Prediccion) #R cuadrado
print("R cuadrado: ", r2)
# Out:
# R cuadrado:  0.46624267398990604

# %% [markdown]
# 7. Realizar las diferentes gráficas que permitan visualizar los resultados del modelo

# %%
plt.figure(figsize=(10, 10))
plt.scatter(Y_test, Prediccion)
plt.xlabel('Valor Real')
plt.ylabel('Predicción')
plt.title('Gráfico de Dispersión')
plt.show()
